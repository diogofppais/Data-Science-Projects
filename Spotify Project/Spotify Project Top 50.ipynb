# %% [markdown]
# # **Project: Are Top Spotify Songs Getting Shorter Over Time?**

# %% [markdown]
# #### **Objective:**

# %% [markdown]
# To determine whether the most popular songs released each year (from 2014 to 2024) are getting shorter in duration over time.

# %% [markdown]
# #### **Challenge:**

# %% [markdown]
# The official Spotify API does not provide the total number of streams per song. Instead, it gives a popularity score (from 0 to 100) which reflects recent activity, not total plays.

# %% [markdown]
# #### **Strategy:**

# %% [markdown]
# **We will:**
#
# 1. Search for the most popular songs released in each year using the Spotify API.
# 2. Record their duration, popularity score, and release date.
# 3. Analyze if the average duration of top songs has decreased over the years.

# %% [markdown]
# #### **Import Libraries Needed**

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import time

# %% [markdown]
# #### **Python Script to Fetch Most Popular Songs Per Year**

# %%
# Set your Spotify API credentials here
CLIENT_ID = '34935f1ddbeb4480a22350f7e4e1e983'
CLIENT_SECRET = '2570074ecf764b6b957b92631d70ea34'

auth_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)

def get_top_tracks_by_year(year, limit=50):
    query = f'year:{year}'
    tracks = []
    offset = 0
    fetched = 0
    max_fetch = 1000  # max search results
    batch_size = 50

    while fetched < max_fetch and len(tracks) < limit:
        try:
            results = sp.search(q=query, type='track', limit=batch_size, offset=offset)
        except spotipy.exceptions.SpotifyException as e:
            print(f"Spotify API error: {e}. Retrying in 5 seconds...")
            time.sleep(5)
            continue
        
        items = results['tracks']['items']
        if not items:
            break
        
        tracks.extend(items)
        fetched += len(items)
        offset += batch_size
        
        time.sleep(0.1)
    
    # Sort by popularity descending
    tracks_sorted = sorted(tracks, key=lambda t: t['popularity'], reverse=True)
    return tracks_sorted[:limit]

def main():
    all_data = []

    for year in range(2014, 2025):
        print(f"Fetching top tracks for {year}...")
        top_tracks = get_top_tracks_by_year(year)

        for track in top_tracks:
            duration_ms = track['duration_ms']
            duration_min = round(duration_ms / 60000, 2)  # convert to minutes with 2 decimals

            all_data.append({
                'Year': year,
                'Track Name': track['name'],
                'Artists': ", ".join([artist['name'] for artist in track['artists']]),
                'Popularity': track['popularity'],
                'Duration (min)': duration_min,
                'Spotify URL': track['external_urls']['spotify']
            })
        
        print(f"Collected {len(top_tracks)} tracks for {year}")
    
    df = pd.DataFrame(all_data)
    df.to_csv('top_tracks_by_year.csv', index=False, encoding='utf-8')
    print("Data saved to top_tracks_by_year.csv")

if __name__ == "__main__":
    main()

df = pd.read_csv('top_tracks_by_year.csv')
df.head()
# Out:
# Fetching top tracks for 2014...
# Collected 50 tracks for 2014
# Fetching top tracks for 2015...
# Collected 50 tracks for 2015
# Fetching top tracks for 2016...
# Collected 50 tracks for 2016
# Fetching top tracks for 2017...
# Collected 50 tracks for 2017
# Fetching top tracks for 2018...
# Collected 50 tracks for 2018
# Fetching top tracks for 2019...
# Collected 50 tracks for 2019
# Fetching top tracks for 2020...
# Collected 50 tracks for 2020
# Fetching top tracks for 2021...
# Collected 50 tracks for 2021
# Fetching top tracks for 2022...
# Collected 50 tracks for 2022
# Fetching top tracks for 2023...
# Collected 50 tracks for 2023
# Fetching top tracks for 2024...
# Collected 50 tracks for 2024
# Data saved to top_tracks_by_year.csv
#    Year                      Track Name                        Artists  \
# 0  2014             A Sky Full of Stars                       Coldplay
# 1  2014                   I Love You So                    The Walters
# 2  2014                          Summer                  Calvin Harris
# 3  2014  Outside (feat. Ellie Goulding)  Calvin Harris, Ellie Goulding
# 4  2014                     Lovers Rock                        TV Girl
#
#    Popularity  Duration (min)  \
# 0          90            4.46
# 1          89            2.67
# 2          88            3.71
# 3          88            3.79
# 4          88            3.57
#
#                                          Spotify URL
# 0  https://open.spotify.com/track/0FDzzruyVECATHX...
# 1  https://open.spotify.com/track/4SqWKzw0CbA05TG...
# 2  https://open.spotify.com/track/6YUTL4dYpB9xZO5...
# 3  https://open.spotify.com/track/7MmG8p0F9N3C4AX...
# 4  https://open.spotify.com/track/6dBUzqjtbnIa1Tw...

# %% [markdown]
# #### **Python Script to Fetch the Image of Each Artist**

# %%
auth_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)

# STEP 1: Load the top tracks dataset
df_tracks = pd.read_csv('top_tracks_by_year.csv')

# STEP 2: Extract the main artist (first listed)
df_tracks['Main Artist'] = df_tracks['Artists'].apply(lambda x: x.split(',')[0].strip())

# STEP 3: Get unique artist names
unique_artists = df_tracks['Main Artist'].drop_duplicates().tolist()

# STEP 4: Function to fetch artist image
def fetch_artist_image(artist_name):
    try:
        result = sp.search(q=artist_name, type='artist', limit=1)
        items = result['artists']['items']
        if items and 'images' in items[0] and items[0]['images']:
            return items[0]['images'][0]['url']
    except Exception as e:
        print(f"Error fetching image for {artist_name}: {e}")
    return None

# STEP 5: Build artist image mapping
artist_data = []
for name in unique_artists:
    print(f"Fetching image for: {name}")
    image_url = fetch_artist_image(name)
    artist_data.append({'Artist': name, 'Image URL': image_url})
    time.sleep(0.1)  # Be nice to the API

# STEP 6: Save to artists.csv
df_artists = pd.DataFrame(artist_data)
df_artists.to_csv('artists.csv', index=False, encoding='utf-8')
print("Saved artist images to artists.csv")
# Out:
# Fetching image for: Coldplay
# Fetching image for: The Walters
# Fetching image for: Calvin Harris
# Fetching image for: TV Girl
# Fetching image for: One Direction
# Fetching image for: J. Cole
# Fetching image for: Justin Bieber
# Fetching image for: Avicii
# Fetching image for: Pitbull
# Fetching image for: MAGIC!
# Fetching image for: Maroon 5
# Fetching image for: WALK THE MOON
# Fetching image for: Vance Joy
# Fetching image for: Ariana Grande
# Fetching image for: Hozier
# Fetching image for: Sam Smith
# Fetching image for: Lana Del Rey
# Fetching image for: Taylor Swift
# Fetching image for: Ed Sheeran
# Fetching image for: Mr. Probz
# Fetching image for: Pharrell Williams
# Fetching image for: George Ezra
# Fetching image for: Sia
# Fetching image for: Nico & Vinz
# Fetching image for: Ty Dolla $ign
# Fetching image for: Route 94
# Fetching image for: Clean Bandit
# Fetching image for: Lilly Wood and The Prick
# Fetching image for: Henrique & Juliano
# Fetching image for: Badoxa
# Fetching image for: Anselmo Ralph
# Fetching image for: Djodje
# Fetching image for: B4
# Fetching image for: Enrique Iglesias
# Fetching image for: Tiago Bettencourt
# Fetching image for: Dillaz
# Fetching image for: Lord Huron
# Fetching image for: Tame Impala
# Fetching image for: The Weeknd
# Fetching image for: Mark Ronson
# Fetching image for: Twenty One Pilots
# Fetching image for: Chase Atlantic
# Fetching image for: Shawn Mendes
# Fetching image for: Bryson Tiller
# Fetching image for: The Neighbourhood
# Fetching image for: Lil Peep
# Fetching image for: Maluma
# Fetching image for: Robin Schulz
# Fetching image for: OMI
# Fetching image for: PARTYNEXTDOOR
# Fetching image for: Kendrick Lamar
# Fetching image for: Travis Scott
# Fetching image for: Adele
# Fetching image for: Madcon
# Fetching image for: Olly Alexander (Years & Years)
# Fetching image for: Beach House
# Fetching image for: Skales
# Fetching image for: Cali Y El Dandee
# Fetching image for: Matheus & Kauan
# Fetching image for: Luan Santana
# Fetching image for: Ari
# Fetching image for: Boy Teddy
# Fetching image for: C4 Pedro
# Fetching image for: Bispo
# Fetching image for: Mariza
# Fetching image for: GROGNation
# Fetching image for: Deejay Telio
# Fetching image for: Calema
# Fetching image for: Don G
# Fetching image for: Ana Moura
# Fetching image for: Drake
# Fetching image for: Frank Ocean
# Fetching image for: DJ Snake
# Fetching image for: Bruno Mars
# Fetching image for: The Chainsmokers
# Fetching image for: James Arthur
# Fetching image for: Lukas Graham
# Fetching image for: Rihanna
# Fetching image for: Seafret
# Fetching image for: KALEO
# Fetching image for: Mike Posner
# Fetching image for: Lost Frequencies
# Fetching image for: Kungs
# Fetching image for: ZAYN
# Fetching image for: Post Malone
# Fetching image for: Kygo
# Fetching image for: Phil Collins
# Fetching image for: Alok
# Fetching image for: MHD
# Fetching image for: CNCO
# Fetching image for: J Balvin
# Fetching image for: Gente De Zona
# Fetching image for: MC Kevinho
# Fetching image for: Danny Ocean
# Fetching image for: Ricky Martin
# Fetching image for: Marília Mendonça
# Fetching image for: Nelson Freitas
# Fetching image for: Matias Damásio
# Fetching image for: Capitão Fausto
# Fetching image for: Plutonio
# Fetching image for: Força Suprema
# Fetching image for: Tyler
# Fetching image for: Imagine Dragons
# Fetching image for: Cigarettes After Sex
# Fetching image for: French Montana
# Fetching image for: Harry Styles
# Fetching image for: Daniel Caesar
# Fetching image for: Måneskin
# Fetching image for: Portugal. The Man
# Fetching image for: Billie Eilish
# Fetching image for: Shakira
# Fetching image for: Ozuna
# Fetching image for: Future
# Fetching image for: Anitta
# Fetching image for: Nicky Jam
# Fetching image for: 1Kilo
# Fetching image for: Matuê
# Fetching image for: Mc IG
# Fetching image for: Mc Livinho
# Fetching image for: MC G15
# Fetching image for: Mc Don Juan
# Fetching image for: Master Jake
# Fetching image for: Richie Campbell
# Fetching image for: Wet Bed Gang
# Fetching image for: Virgul
# Fetching image for: Xutos & Pontapés
# Fetching image for: Yasmine
# Fetching image for: Piruka
# Fetching image for: Os Quatro e Meia
# Fetching image for: Lhast
# Fetching image for: Lady Gaga
# Fetching image for: Sean Paul
# Fetching image for: Juice WRLD
# Fetching image for: Marshmello
# Fetching image for: Anuel AA
# Fetching image for: Calum Scott
# Fetching image for: 6ix9ine
# Fetching image for: Bad Bunny
# Fetching image for: MC L da Vinte
# Fetching image for: Parcels
# Fetching image for: Xamã
# Fetching image for: Pixote
# Fetching image for: Mc Kevin
# Fetching image for: Papillon
# Fetching image for: DJ Dadda
# Fetching image for: Fernando Daniel
# Fetching image for: Rapaz 100 Juiz
# Fetching image for: Sam The Kid
# Fetching image for: Diogo Piçarra
# Fetching image for: T-Rex
# Fetching image for: Bárbara Bandeira
# Fetching image for: Valas
# Fetching image for: Lewis Capaldi
# Fetching image for: Chris Brown
# Fetching image for: Lil Tecca
# Fetching image for: Dj Guuga
# Fetching image for: Rauw Alejandro
# Fetching image for: Luis Fonsi
# Fetching image for: Diego & Victor Hugo
# Fetching image for: Beéle
# Fetching image for: Daddy Yankee
# Fetching image for: MC Kevin o Chris
# Fetching image for: Gilsons
# Fetching image for: MC Du Black
# Fetching image for: ANAVITÓRIA
# Fetching image for: Pk
# Fetching image for: Mc Leozin
# Fetching image for: MC JottaPê
# Fetching image for: NAPA
# Fetching image for: Slow J
# Fetching image for: Phoenix Rdc
# Fetching image for: Nininho Vaz Maia
# Fetching image for: Dream Supplier
# Fetching image for: Charli xcx
# Fetching image for: Glass Animals
# Fetching image for: Hotel Ugly
# Fetching image for: Ozzy Osbourne
# Fetching image for: Miley Cyrus
# Fetching image for: Dua Lipa
# Fetching image for: Gracie Abrams
# Fetching image for: Don Miguelo
# Fetching image for: Don Toliver
# Fetching image for: Boza
# Fetching image for: Jay Wheeler
# Fetching image for: Orochi
# Fetching image for: L7NNON
# Fetching image for: FRANKIEONTHEGUITAR
# Fetching image for: Soraia Ramos
# Fetching image for: Domingues
# Fetching image for: Gama WNTD
# Fetching image for: Van Zee
# Fetching image for: Gson
# Fetching image for: Yuri NR5
# Fetching image for: X.L.T
# Fetching image for: Olivia Rodrigo
# Fetching image for: Metallica
# Fetching image for: Tate McRae
# Fetching image for: Tory Lanez
# Fetching image for: Elton John
# Fetching image for: Farruko
# Fetching image for: Grupo Menos É Mais
# Fetching image for: MeditarSons
# Fetching image for: Morad
# Fetching image for: Francis Mercier
# Fetching image for: MC Cabelinho
# Fetching image for: Teto
# Fetching image for: Mc Poze do Rodo
# Fetching image for: Julinho Ksd
# Fetching image for: Maninho
# Fetching image for: Bárbara Tinoco
# Fetching image for: Djo
# Fetching image for: David Guetta
# Fetching image for: SZA
# Fetching image for: Noah Kahan
# Fetching image for: OneRepublic
# Fetching image for: Misa Bee
# Fetching image for: Rosa Linn
# Fetching image for: Bizarrap
# Fetching image for: Rema
# Fetching image for: LF SYSTEM
# Fetching image for: Benson Boone
# Fetching image for: iñigo quintero
# Fetching image for: Manuel Turizo
# Fetching image for: Beny Jr
# Fetching image for: Bob Sinclar
# Fetching image for: WIU
# Fetching image for: KayBlack
# Fetching image for: Veigh
# Fetching image for: PEDRO SAMPAIO
# Fetching image for: Pedro Abrunhosa
# Fetching image for: Irina Barros
# Fetching image for: D.A.M.A
# Fetching image for: Anjos
# Fetching image for: Sara Correia
# Fetching image for: Nena
# Fetching image for: Kappa Jotta
# Fetching image for: Mizzy Miles
# Fetching image for: Luís Trigacheiro
# Fetching image for: Teddy Swims
# Fetching image for: The Kid LAROI
# Fetching image for: Feid
# Fetching image for: CYRIL
# Fetching image for: Disclosure
# Fetching image for: Tyla
# Fetching image for: KAROL G
# Fetching image for: Dimitri Vegas & Like Mike
# Fetching image for: Myke Towers
# Fetching image for: Quevedo
# Fetching image for: Loreen
# Fetching image for: Wakyin
# Fetching image for: Dj Tchouzen
# Fetching image for: GIMS
# Fetching image for: DELLAFUENTE
# Fetching image for: Borges
# Fetching image for: DENNIS
# Fetching image for: Mc Paiva ZS
# Fetching image for: Nuno Ribeiro
# Fetching image for: LON3R JOHNY
# Fetching image for: Buba Espinho
# Fetching image for: sombr
# Fetching image for: Alex Warren
# Fetching image for: ROSÉ
# Fetching image for: Chappell Roan
# Fetching image for: HUGEL
# Fetching image for: Gigi Perez
# Fetching image for: ATLXS
# Fetching image for: Myles Smith
# Fetching image for: Alleh
# Fetching image for: Lola Young
# Fetching image for: Adam Port
# Fetching image for: MoBlack
# Fetching image for: Nilo
# Fetching image for: DJ TOPO
# Fetching image for: Oruam
# Fetching image for: DJ NATAN 22
# Fetching image for: Boladin 211
# Fetching image for: MC Tuto
# Fetching image for: J. Eskine
# Fetching image for: DJ Malvado
# Fetching image for: Bluay
# Fetching image for: Ivandro
# Saved artist images to artists.csv

# %% [markdown]
# #### **Next Steps**

# %% [markdown]
# Import the csv file into PowerBI and starting making the analysis and determine whether the most popular songs released each year (from 2014 to 2024) are getting shorter in duration over time or not.
